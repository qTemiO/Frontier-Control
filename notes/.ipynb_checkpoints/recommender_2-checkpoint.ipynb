# %% [markdown]
# ## Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import random
from tqdm import tqdm
from gensim.models import Word2Vec 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings;
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a49532cd640a> in <module>
#       3 import random
#       4 from tqdm import tqdm
# ----> 5 from gensim.models import Word2Vec
#       6 import matplotlib.pyplot as plt
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'gensim'

# %%
df_raw = pd.read_excel('tnved-CIS-02.xls')

# %% [markdown]
# Let's take a quick look at our data. You can __download it from [here](https://archive.ics.uci.edu/ml/machine-learning-databases/00352/).__

# %%
df_raw.head()
# Out:
#         TNVED  Cust_ID                                Name Unit  \
# 0        0101   6116.0  Лошади, ослы, мулы и лошаки живые:  NaN
# 1  0101210000   5129.0  ––чистопородные племенные животные   шт
# 2      010129   6730.0                           ––прочие:  NaN
# 3  0101291000   6689.0                          –––убойные   шт
# 4  0101299000   5596.0                           –––прочие   шт
#
#                                            FULL_TEXT
# 0                 ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ:
# 1   ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИ...
# 2   ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 3   ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 4   ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...

# %%
df_raw.shape
# Out:
# (15927, 5)

# %% [markdown]
# ## Treat Missing Data

# %%
# check for missing values
df_raw.isnull().sum()
# Out:
# TNVED           0
# Cust_ID       135
# Name           31
# Unit         4375
# FULL_TEXT      31
# dtype: int64

# %% [markdown]
# <br>
# Since we have sufficient data, we will drop all the rows with missing values.

# %%
# remove missing values
df_raw.dropna(inplace=True)

# again check missing values
df_raw.isnull().sum()
# Out:
# TNVED        0
# Cust_ID      0
# Name         0
# Unit         0
# FULL_TEXT    0
# dtype: int64

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Let's convert the StockCode to string datatype.

# %%
df_raw['TNVED']= df_raw['TNVED'].astype(str)

# %% [markdown]
# Let's check out the number of unique customers in our dataset.

# %%
customers = df_raw["Cust_ID"].unique().tolist()
len(customers)
# Out:
# 1996

# %%
import string
import nltk
import nltk
nltk.download('stopwords')
lst_stopwords = nltk.corpus.stopwords.words('russian')
lst_stopwords.append('прочие')
lst_stopwords.append('включая')

lst_stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jora\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между',
#  'прочие',
#  'включая']

# %%
def clean_text(text, tokenizer, stopwords):
    """Pre-process text and generate tokens

    Args:
        text: Text to tokenize.

    Returns:
        Tokenized text.
    """
    text = str(text).lower()  # Lowercase words
    text = re.sub(r"\[(.*?)\]", "", text)  # Remove [+XYZ chars] in content
    text = re.sub(r"\s+", " ", text)  # Remove multiple spaces in content
    text = re.sub(r"\w+…|…", "", text)  # Remove ellipsis (and last word)
    text = re.sub(r"(?<=\w)-(?=\w)", " ", text)  # Replace dash between words
    text = re.sub(
        f"[{re.escape(string.punctuation)}]", "", text
    )  # Remove punctuation

    tokens = tokenizer(text)  # Get tokens from text
    tokens = [t for t in tokens if not t in lst_stopwords]  # Remove stopwords
    tokens = ["" if t.isdigit() else t for t in tokens]  # Remove digits
    tokens = [t for t in tokens if len(t) > 1]  # Remove short tokens
    return tokens

# %%
text_columns = ['FULL_TEXT']

df = df_raw
df[ "FULL_TEXT"] = df[ "FULL_TEXT"].fillna(" ")

for col in text_columns:
    df[col] = df[col].astype(str)

# Create text column based on title, description, and content
df["text"] = df[text_columns].apply(lambda x: " | ".join(x), axis=1)
df["tokens"] = df["text"].map(lambda x: clean_text(x, word_tokenize, lst_stopwords))

#Remove duplicated after preprocessing
_, idx = np.unique(df["tokens"], return_index=True)
df = df.iloc[idx, :]

# Remove empty values
df = df.loc[df.tokens.map(lambda x: len(x) > 0), ["text", "tokens"]]

print(f"Original dataframe: {df_raw.shape}")
print(f"Pre-processed dataframe: {df.shape}")
# Out:
# Original dataframe: (11454, 7)
# Pre-processed dataframe: (10686, 2)

# %%
df_raw
# Out:
#             TNVED  Cust_ID                                Name Unit  \
# 1      0101210000   5129.0  ––чистопородные племенные животные   шт
# 3      0101291000   6689.0                          –––убойные   шт
# 4      0101299000   5596.0                           –––прочие   шт
# 5      0101300000   5117.0                               –ослы   шт
# 6      0101900000   5686.0                             –прочие   шт
# ...           ...      ...                                 ...  ...
# 15785  9506620000   5694.0                     ––мячи надувные   шт
# 15787  9506691000   6802.0          –––мячи для крикета и поло   шт
# 15788  9506699000   5291.0                           –––прочие   шт
# 15790  9506701000   5769.0                    ––ледовые коньки  пар
# 15791  9506703000   5572.0                  ––роликовые коньки  пар
#
#                                                FULL_TEXT  \
# 1       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИ...
# 3       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 4       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 5                ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ОСЛЫ
# 6              ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ПРОЧИЕ
# ...                                                  ...
# 15785   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15787   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15788   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15790   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15791   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
#
#                                                     text  \
# 1       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИ...
# 3       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 4       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 5                ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ОСЛЫ
# 6              ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ПРОЧИЕ
# ...                                                  ...
# 15785   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15787   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15788   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15790   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15791   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
#
#                                                   tokens
# 1      [лошади, ослы, мулы, лошаки, живые, лошади, чи...
# 3      [лошади, ослы, мулы, лошаки, живые, лошади, уб...
# 4            [лошади, ослы, мулы, лошаки, живые, лошади]
# 5              [лошади, ослы, мулы, лошаки, живые, ослы]
# 6                    [лошади, ослы, мулы, лошаки, живые]
# ...                                                  ...
# 15785  [инвентарь, оборудование, занятий, общей, физк...
# 15787  [инвентарь, оборудование, занятий, общей, физк...
# 15788  [инвентарь, оборудование, занятий, общей, физк...
# 15790  [инвентарь, оборудование, занятий, общей, физк...
# 15791  [инвентарь, оборудование, занятий, общей, физк...
#
# [11454 rows x 7 columns]

# %% [markdown]
# It is a good practice to set aside a small part of the dataset for validation purpose. Therefore, I will use data of 90% of the customers to create word2vec embeddings. Let's split the data.

# %%
# shuffle customer ID's
random.shuffle(customers)

# extract 90% of customer ID's
customers_train = [customers[i] for i in range(round(0.9*len(customers)))]

# split data into train and validation set
train_df = df_raw[df_raw['Cust_ID'].isin(customers_train)]
validation_df = df_raw[~df_raw['Cust_ID'].isin(customers_train)]train_df

# %%
# Out:
#             TNVED  Cust_ID                                Name Unit  \
# 1      0101210000   5129.0  ––чистопородные племенные животные   шт
# 3      0101291000   6689.0                          –––убойные   шт
# 4      0101299000   5596.0                           –––прочие   шт
# 5      0101300000   5117.0                               –ослы   шт
# 6      0101900000   5686.0                             –прочие   шт
# ...           ...      ...                                 ...  ...
# 15784  9506610000   5595.0                  ––мячи для тенниса   шт
# 15787  9506691000   6802.0          –––мячи для крикета и поло   шт
# 15788  9506699000   5291.0                           –––прочие   шт
# 15790  9506701000   5769.0                    ––ледовые коньки  пар
# 15791  9506703000   5572.0                  ––роликовые коньки  пар
#
#                                                FULL_TEXT  \
# 1       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИ...
# 3       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 4       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 5                ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ОСЛЫ
# 6              ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ПРОЧИЕ
# ...                                                  ...
# 15784   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15787   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15788   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15790   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15791   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
#
#                                                     text  \
# 1       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИ...
# 3       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 4       ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ПР...
# 5                ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ОСЛЫ
# 6              ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ПРОЧИЕ
# ...                                                  ...
# 15784   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15787   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15788   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15790   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
# 15791   ИНВЕНТАРЬ И ОБОРУДОВАНИЕ ДЛЯ ЗАНЯТИЙ ОБЩЕЙ ФИ...
#
#                                                   tokens
# 1      [лошади, ослы, мулы, лошаки, живые, лошади, чи...
# 3      [лошади, ослы, мулы, лошаки, живые, лошади, уб...
# 4            [лошади, ослы, мулы, лошаки, живые, лошади]
# 5              [лошади, ослы, мулы, лошаки, живые, ослы]
# 6                    [лошади, ослы, мулы, лошаки, живые]
# ...                                                  ...
# 15784  [инвентарь, оборудование, занятий, общей, физк...
# 15787  [инвентарь, оборудование, занятий, общей, физк...
# 15788  [инвентарь, оборудование, занятий, общей, физк...
# 15790  [инвентарь, оборудование, занятий, общей, физк...
# 15791  [инвентарь, оборудование, занятий, общей, физк...
#
# [10323 rows x 7 columns]

# %% [markdown]
# Let's create sequences of purchases made by the customers in the dataset for both the train and validation set.

# %%
# list to capture purchase history of the customers
purchases_train = []

# populate the list with the product codes
for i in tqdm(customers_train):
    temp = train_df[train_df["Cust_ID"] == i]["TNVED"].tolist()
    purchases_train.append(temp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1796/1796 [00:00<00:00, 5250.31it/s]

# %%
# list to capture purchase history of the customers
purchases_val = []

# populate the list with the product codes
for i in tqdm(validation_df['Cust_ID'].unique()):
    temp = validation_df[validation_df["Cust_ID"] == i]["TNVED"].tolist()
    purchases_val.append(temp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 4877.75it/s]

# %%
# Out:
# [['0102219000',
#   '2826300000',
#   '4407296800',
#   '4810923000',
#   '5101110000',
#   '8518408001',
#   '8716310000'],
#  ['0103921100',
#   '0714201000',
#   '3401209000',
#   '4811510001',
#   '7312106900',
#   '8462399900'],
#  ['0104101000',
#   '2710129001',
#   '2710192500',
#   '4202390000',
#   '6107290000',
#   '7223009900',
#   '8424890009'],
#  ['0105130000', '2845901000', '7013331100', '7219219000', '9503002900'],
#  ['0105940000', '2009315101', '9405608000'],
#  ['0106141010',
#   '0207456101',
#   '2205901000',
#   '3208901100',
#   '4503900000',
#   '8408101900',
#   '8426490091',
#   '8472903000'],
#  ['0106190091', '0307499900', '1701139011', '7608100000', '8443110000'],
#  ['0106410008',
#   '2517410000',
#   '5903209000',
#   '8108300000',
#   '8544601000',
#   '8545110081',
#   '9206000000'],
#  ['0201202001', '2009491908', '4102101000', '7228502000'],
#  ['0201203002',
#   '1210201000',
#   '1602321900',
#   '2008996708',
#   '3824909709',
#   '3922100000'],
#  ['0201205002', '0304833000', '1005101100', '7615109001'],
#  ['0202201002', '0207266009', '4415209000', '7307999001', '8703231922'],
#  ['0202203001',
#   '1101001500',
#   '4408311109',
#   '7306307200',
#   '8523519900',
#   '9004101000'],
#  ['0202209008',
#   '0207541001',
#   '0602903000',
#   '0805509000',
#   '2008405100',
#   '4702000000',
#   '6907908009',
#   '7210128000',
#   '7310219900'],
#  ['0202305006', '2902190000', '4114109000', '5205230000', '9403401000'],
#  ['0202309006', '2009891903', '2934309000', '3102900000', '7606129900'],
#  ['0203191509',
#   '0305640000',
#   '1103202000',
#   '7005103000',
#   '7220208900',
#   '8439999000',
#   '8544300008',
#   '8802120001'],
#  ['0203195901',
#   '0207263009',
#   '0207448109',
#   '2909110000',
#   '7208390000',
#   '8607191001',
#   '9022130000'],
#  ['0203199009', '0901210008', '1701141014', '2707998000', '8421210009'],
#  ['0203229009', '1104129000', '6205908001'],
#  ['0204100000',
#   '0905200000',
#   '2941203000',
#   '3004100002',
#   '4302309550',
#   '7321811000',
#   '7411109000',
#   '8457101002',
#   '8802400049'],
#  ['0204423000',
#   '0204505100',
#   '1602394000',
#   '2508500000',
#   '8207903000',
#   '8473211000'],
#  ['0204431000',
#   '1806905009',
#   '2006003800',
#   '5602290000',
#   '7610901000',
#   '8523411000'],
#  ['0204507900', '2811191000', '3306900000', '4301600070', '8704313908'],
#  ['0206109500',
#   '0706100001',
#   '2606000000',
#   '2844101000',
#   '3505105000',
#   '7220208109',
#   '7307993000'],
#  ['0207113009',
#   '0303411000',
#   '0406908700',
#   '2909410000',
#   '5402200001',
#   '6106200000',
#   '6301901000',
#   '6907902001',
#   '7208519100',
#   '8418102008',
#   '8467291000'],
#  ['0207136001', '2204216800', '2804800000', '3916100000', '8462998009'],
#  ['0207142001', '5301300000', '6403911100', '7102390000'],
#  ['0207146009',
#   '1604199100',
#   '2009904908',
#   '4407253000',
#   '6104590000',
#   '8708999309'],
#  ['0207147001', '2842908000', '7318165000', '8506101800', '9405403501'],
#  ['0207149109',
#   '2008609000',
#   '3006920000',
#   '3702530000',
#   '8444001000',
#   '8605000001'],
#  ['0207149909',
#   '0210993100',
#   '0909610000',
#   '1008600000',
#   '4302193090',
#   '4302309570',
#   '4819200000',
#   '6109902000'],
#  ['0207262009', '3808913000', '4106409000', '5601219000', '9018902000'],
#  ['0207273001',
#   '2917200000',
#   '6006100000',
#   '7010901000',
#   '7304511809',
#   '8528591009'],
#  ['0207277009', '2204219800', '8531202009', '9205905000'],
#  ['0207413009',
#   '0810500000',
#   '1104223000',
#   '1905909000',
#   '2004101000',
#   '2844500000',
#   '4819300001',
#   '9503002100'],
#  ['0207428001',
#   '0308210000',
#   '1605630000',
#   '7007119000',
#   '7214919000',
#   '8411810009',
#   '8418402009'],
#  ['0207447101', '2008994800', '8421290002'],
#  ['0207449909',
#   '0304992900',
#   '0809100000',
#   '2844202500',
#   '2939110000',
#   '3920995200',
#   '4411121000',
#   '6403599900',
#   '6811890000',
#   '8418211000',
#   '8447900009',
#   '8504409008'],
#  ['0207454101', '2101110018', '4407949900'],
#  ['0207530009',
#   '2829908000',
#   '2906190000',
#   '4805199000',
#   '7507120000',
#   '8431410000',
#   '8467910000',
#   '8517693100'],
#  ['0207545101', '0209101900', '8408203109'],
#  ['0207545109', '5402320000', '5801260000', '8501522001'],
#  ['0207602101',
#   '0307119000',
#   '1503001100',
#   '3906901000',
#   '3925902000',
#   '5515111000',
#   '6005210000',
#   '7226920000',
#   '8419390001',
#   '8483105000',
#   '8702101996',
#   '9031410000'],
#  ['0207608109',
#   '0306179900',
#   '0405109000',
#   '4016995709',
#   '4818109000',
#   '6105909000',
#   '6804230000',
#   '6914100000',
#   '7001009100'],
#  ['0208401000',
#   '1901901100',
#   '2008303100',
#   '3914000000',
#   '4908900000',
#   '8443919900',
#   '8702903928'],
#  ['0208408000', '1205109000', '3702319100', '6912009000', '8536900100'],
#  ['0209109000', '1001912000', '1205900009', '2102201900', '2302309000'],
#  ['0210111900',
#   '0303190000',
#   '1512119909',
#   '2914610000',
#   '4408908505',
#   '4418109000',
#   '7318152000',
#   '8519818101'],
#  ['0210113100',
#   '1701121001',
#   '5609000000',
#   '7010905100',
#   '7317001000',
#   '8112211000'],
#  ['0210119000',
#   '0210921000',
#   '1104239900',
#   '6205300000',
#   '8465101000',
#   '9301900000'],
#  ['0210198100',
#   '0307899000',
#   '2904200000',
#   '8425390003',
#   '8539221000',
#   '9101110000'],
#  ['0210929200',
#   '0303419000',
#   '0304719000',
#   '2905141000',
#   '5107205900',
#   '8528724000',
#   '8708939009'],
#  ['0210993900',
#   '2713120009',
#   '3204170000',
#   '4010330000',
#   '8430690008',
#   '8528510000',
#   '8542327500',
#   '8603100001'],
#  ['0301921000',
#   '1104199900',
#   '2302500000',
#   '4016995201',
#   '4407959900',
#   '8511900007',
#   '8703239028'],
#  ['0301923000', '2803000000', '6305109000', '8207507000'],
#  ['0302359100',
#   '0307493800',
#   '1207100000',
#   '2710196601',
#   '3002200001',
#   '7216321900',
#   '7307239000',
#   '8421392001',
#   '8541500000'],
#  ['0302398000',
#   '0303691000',
#   '0307399000',
#   '1604195000',
#   '2008199100',
#   '5113000000'],
#  ['0302433000', '0808108007', '2937290000', '7217101000'],
#  ['0302849000', '4403999502', '6005341000', '8424813000'],
#  ['0302896000',
#   '1701910023',
#   '2902300000',
#   '5514420000',
#   '8714950000',
#   '9202109000'],
#  ['0303240000', '2208905602', '9018120000'],
#  ['0303429000',
#   '0303892100',
#   '0713900000',
#   '2008977400',
#   '2619002000',
#   '4806200000',
#   '5911200000',
#   '6108310000',
#   '7010904500',
#   '7019909100',
#   '8523499101',
#   '9013803000'],
#  ['0303459900',
#   '0709599000',
#   '0808108001',
#   '4408313001',
#   '6404209000',
#   '7013375100',
#   '8453800000'],
#  ['0303539000',
#   '0304956000',
#   '5402480000',
#   '7415100000',
#   '8479899708',
#   '8516802009'],
#  ['0303549000', '5306103000', '8418108009'],
#  ['0303633000', '4302307190', '7214993900', '8542311001', '8711900000'],
#  ['0303661100',
#   '3501909000',
#   '4707301000',
#   '7406100000',
#   '8536691000',
#   '9015201000',
#   '9021109000'],
#  ['0303661300',
#   '2903391500',
#   '4101208000',
#   '4601940500',
#   '5407201900',
#   '8460909005',
#   '8461501909',
#   '8483409000'],
#  ['0303695000',
#   '1103199009',
#   '1515906000',
#   '2206003100',
#   '4410190001',
#   '5408340000',
#   '7202118000',
#   '8408209902',
#   '8453200000'],
#  ['0303891010', '2920903000', '5212221000', '8528728000', '9017203900'],
#  ['0303896000',
#   '0710809500',
#   '4601941000',
#   '6303120000',
#   '8414108100',
#   '8451803001',
#   '8536611000',
#   '8713900000'],
#  ['0303896500',
#   '5210410000',
#   '5804109000',
#   '7306191000',
#   '8701209090',
#   '8704239101',
#   '8803300000'],
#  ['0304595000', '0707000506', '8460211100'],
#  ['0304749000',
#   '2009719909',
#   '2825300000',
#   '4301807079',
#   '8512301009',
#   '8542319011',
#   '8702901120',
#   '9030203001'],
#  ['0304839000', '2514000000', '8412298101', '8528498009'],
#  ['0304949000',
#   '1214909000',
#   '2008111000',
#   '2204299401',
#   '3707902000',
#   '4202129100',
#   '7209179001',
#   '8111001900',
#   '8475900000',
#   '8528719000',
#   '8703331100'],
#  ['0305493000', '3809109000', '5607491900', '9304000000'],
#  ['0305620000',
#   '0710806900',
#   '0712310000',
#   '7209171000',
#   '8301300000',
#   '8518293000'],
#  ['0305790001', '7606119900', '8104300000'],
#  ['0306161000',
#   '0811908000',
#   '0908310000',
#   '1106201000',
#   '2002109000',
#   '8445309001',
#   '8702101110'],
#  ['0306199000',
#   '0406901800',
#   '1701139015',
#   '1902401000',
#   '2517300000',
#   '6205908009',
#   '8464201900'],
#  ['0306241000',
#   '0407299000',
#   '8207403000',
#   '8466937000',
#   '8529109500',
#   '8534009000'],
#  ['0306248000', '7318156100', '8207703500', '8516330000', '8901101001'],
#  ['0306298100',
#   '3206420000',
#   '4403491000',
#   '6902100000',
#   '8504405501',
#   '8526920009',
#   '9004909001'],
#  ['0306298900',
#   '0808400000',
#   '1101009000',
#   '1802000000',
#   '6104420000',
#   '6110113000',
#   '7321190000',
#   '8443911000',
#   '8703249098',
#   '8801009000'],
#  ['0307491100', '1104193000', '2712901100'],
#  ['0307601000',
#   '2204299609',
#   '7507110000',
#   '7605190000',
#   '8462411002',
#   '8523493100'],
#  ['0307991000', '9015900000', '9017801000'],
#  ['0307991300', '3910000002', '9405109801'],
#  ['0307991700',
#   '1209999900',
#   '1605690000',
#   '2712201000',
#   '2937110000',
#   '8440109000',
#   '8714993000'],
#  ['0308903000', '1006302100', '2204298201'],
#  ['0402291500', '0910993300', '6403511900', '8408906709', '8704229904'],
#  ['0403101900',
#   '1515309000',
#   '2009120008',
#   '4009310000',
#   '6204639000',
#   '7419100000',
#   '8536500700',
#   '8708409109'],
#  ['0403109300',
#   '1516209609',
#   '3105909900',
#   '7318220002',
#   '8430690001',
#   '8519814500'],
#  ['0403903300',
#   '0404902300',
#   '0406903201',
#   '1602392100',
#   '1604207000',
#   '1703900000',
#   '2101110093',
#   '2909440000',
#   '8536500300'],
#  ['0404101201', '0404107600', '1701910032', '2102103100', '7323939000'],
#  ['0406201000', '2930903000', '3002200002', '8517691000'],
#  ['0406303900', '1522003900', '2620190000', '6403591100'],
#  ['0406907800', '2009893602', '8707109000', '8708709901'],
#  ['0406909909',
#   '2839190000',
#   '5512210000',
#   '7226200000',
#   '8501109900',
#   '8804000000'],
#  ['0407191100',
#   '2103909009',
#   '2206008901',
#   '2918110000',
#   '8207709000',
#   '8527139900'],
#  ['0407909000', '1806310000', '2707301000', '9022900000'],
#  ['0505900000', '2009901903', '4707309000', '9108200000'],
#  ['0511919090', '8433115100'],
#  ['0511998523', '2926100000', '8211100000', '8428310000', '9018311009'],
#  ['0601109000', '1008900000', '4107121900', '8506101100', '8512909009'],
#  ['0601201000',
#   '2008505900',
#   '2917140000',
#   '5211120000',
#   '7408290000',
#   '8703229010',
#   '9018903000'],
#  ['0602201000', '1904109000', '2009393909', '4010120000', '7306119000'],
#  ['0602902000', '3004400001', '5516910000', '8704219908'],
#  ['0707000501', '3917211000', '5804291000', '8460211900', '8705901001'],
#  ['0709939000', '1004900000', '6506108000'],
#  ['0712200000',
#   '0814000000',
#   '2929900000',
#   '2939300000',
#   '3903190009',
#   '4802200000',
#   '8408205102',
#   '9306290000'],
#  ['0713320000',
#   '2008991900',
#   '3920621901',
#   '4814907009',
#   '6115290000',
#   '6203423500',
#   '6402999800'],
#  ['0714901200', '1605211000', '8422400003', '8530900000'],
#  ['0801190000', '6102201000', '8701902500'],
#  ['0802908500',
#   '2509000000',
#   '3907911000',
#   '4905100000',
#   '6306300000',
#   '7210490001',
#   '8536700001'],
#  ['0803109000', '3004500009', '9030840001', '9032200000'],
#  ['0808101000',
#   '2204294809',
#   '2914110000',
#   '5211491000',
#   '6601992000',
#   '7315821000',
#   '7317006100',
#   '8483308008',
#   '8540208000'],
#  ['0808108003',
#   '2901220000',
#   '2915130000',
#   '4104111000',
#   '4104495100',
#   '7304220009',
#   '8413703500',
#   '8531908508'],
#  ['0812904000', '8418308009', '8541600000', '9306909000'],
#  ['0902300001',
#   '2208904800',
#   '7211190000',
#   '7216690000',
#   '7411219000',
#   '8479600000',
#   '8714941000'],
#  ['0910991000',
#   '1103119000',
#   '2008977200',
#   '2009111908',
#   '6107110000',
#   '6204339000',
#   '7202600000',
#   '7209189100',
#   '7326909803',
#   '8443329109',
#   '9029203101'],
#  ['1006209400',
#   '1701910015',
#   '2920190000',
#   '2933610000',
#   '5206130000',
#   '6211324200',
#   '7305390000',
#   '7403190000'],
#  ['1006306500',
#   '1806101500',
#   '3902200000',
#   '3920108100',
#   '4418720000',
#   '4601949000',
#   '7008008900',
#   '7304900000',
#   '8214100000'],
#  ['1104290500',
#   '5212231000',
#   '7306199000',
#   '8208900000',
#   '8541210000',
#   '8704221000'],
#  ['1108110000',
#   '2501005100',
#   '3904210000',
#   '3920300000',
#   '4408903500',
#   '4420101100',
#   '6001210000',
#   '8441101001',
#   '8486303000',
#   '9031499000'],
#  ['1207300000',
#   '2005992000',
#   '2008205100',
#   '2009902903',
#   '3202100000',
#   '4403410000',
#   '4408312109',
#   '5001000000',
#   '6301201000',
#   '7202291000'],
#  ['1207600000',
#   '2101309900',
#   '2827350000',
#   '3004500001',
#   '5513120000',
#   '8508190001'],
#  ['1208100000', '2518100000', '5403390000', '8523599300', '8903991000'],
#  ['1502901000',
#   '7409190000',
#   '8408109100',
#   '8513900000',
#   '8523293902',
#   '9110111000'],
#  ['1504309000', '1701910021', '2009891902', '3904100091', '8545110089'],
#  ['1511901100', '2844305500', '5512991000', '7404009100', '8462419001'],
#  ['1512119901',
#   '3913100000',
#   '5703308801',
#   '8407349908',
#   '8528591001',
#   '9403109300'],
#  ['1513111000', '8454900000', '8544499101'],
#  ['1515191000', '4016995209', '5801330000', '8486209004'],
#  ['1515901100',
#   '1701131026',
#   '2710194600',
#   '6103290000',
#   '8441102000',
#   '9018329000'],
#  ['1602329000',
#   '2206005100',
#   '3926909707',
#   '4911910000',
#   '6211331000',
#   '8707101000',
#   '9102120000'],
#  ['1605590000', '5505101000', '6304110000', '8422300001'],
#  ['1701910033',
#   '4301600020',
#   '4902100000',
#   '6204221000',
#   '8431310000',
#   '8545901000'],
#  ['1702608000',
#   '2921220000',
#   '3811290000',
#   '5514199000',
#   '8478900000',
#   '8504509500',
#   '8702109924'],
#  ['1703100000', '3203009000', '5702321000', '7218992000'],
#  ['1902199000', '2008932100', '3920992800'],
#  ['1905409000', '6202131000', '6203329000'],
#  ['2001905000',
#   '2905490000',
#   '5702421000',
#   '7226110000',
#   '8704213904',
#   '9106900000'],
#  ['2005208000', '4810929009', '7020000800', '8421210001'],
#  ['2005993000',
#   '4104499000',
#   '5111301000',
#   '7019191009',
#   '7312108309',
#   '8418910000',
#   '8536700004',
#   '8708503501',
#   '8802400047'],
#  ['2006003500',
#   '2815200000',
#   '2912410000',
#   '2938909000',
#   '4005990000',
#   '8702903993'],
#  ['2008606000', '3920102500', '6104610001', '7326905000', '8803200000'],
#  ['2008703900', '2009210001', '3404200000', '4907001090', '8101970000'],
#  ['2008979800', '2933291000'],
#  ['2008994500',
#   '4415101000',
#   '5904100000',
#   '7304240005',
#   '8483102102',
#   '8802400043'],
#  ['2009719901',
#   '2936290000',
#   '6402993900',
#   '7616991001',
#   '8413506900',
#   '8427101000',
#   '8539299200',
#   '9026900002',
#   '9401908001'],
#  ['2106903000', '2508400000', '6206300000', '7325910000', '8108906008'],
#  ['2106909809',
#   '3105510000',
#   '3403191000',
#   '3808500000',
#   '3920738000',
#   '4008190000',
#   '8528691000',
#   '8703241010'],
#  ['2204211900', '7222203900', '8533409000'],
#  ['2204212600', '3003200000', '6201131000', '6913909800'],
#  ['2204294801',
#   '2401103500',
#   '5111909900',
#   '6301209001',
#   '8411121000',
#   '8544200001',
#   '9113101000',
#   '9403105800'],
#  ['2207200000', '2804210000', '7318210001', '8106009000'],
#  ['2208509100',
#   '2818200000',
#   '4414001000',
#   '5810919000',
#   '8205700000',
#   '8207809000'],
#  ['2208509900',
#   '2208905400',
#   '2825906000',
#   '4002490000',
#   '6112411000',
#   '7013379100',
#   '7226912000',
#   '8426300009',
#   '8480100000'],
#  ['2302401000', '2905220000', '4202199000', '6209300000', '8703901010'],
#  ['2401203500', '2523900000', '3301249000', '3816000000', '8705200001'],
#  ['2403991000',
#   '4002192000',
#   '4411931000',
#   '5208290000',
#   '6005315000',
#   '7305110008',
#   '8516605000',
#   '8708999709'],
#  ['2501003100',
#   '4408101504',
#   '4421909800',
#   '6210300000',
#   '7228307000',
#   '7419999000'],
#  ['2518300000',
#   '3206493000',
#   '7615200000',
#   '8425390002',
#   '8523809101',
#   '8547200001',
#   '9113900000'],
#  ['2620600000', '7217902000', '7318155100', '8708405001', '9114400000'],
#  ['2621100000',
#   '2827491000',
#   '2921194000',
#   '3902909000',
#   '4704190000',
#   '5911100000',
#   '6302910000'],
#  ['2710196409', '2909303500', '8412218002', '8480309000'],
#  ['2713110000', '7320909002', '8428320000', '8519891900'],
#  ['2804501000', '6107990000', '7208902000', '7307910000', '8536501109'],
#  ['2806100000', '7616999008', '8407905000', '8460401000', '8704219903'],
#  ['2830901100', '3505109000', '6211431000', '7203900000', '9028901000'],
#  ['2840201000',
#   '2905170000',
#   '5501100009',
#   '6204699000',
#   '7213912000',
#   '7219349009',
#   '8443321003'],
#  ['2902900000', '8402199001'],
#  ['2914310000', '5110000000'],
#  ['2915500000', '3921906000', '4501100000', '7319901000'],
#  ['2918210000', '8405100009', '9031491000'],
#  ['2919900000',
#   '2939990000',
#   '3505205000',
#   '5408310000',
#   '7304293009',
#   '7308300000',
#   '8535301000'],
#  ['3105200000',
#   '3402120000',
#   '4302200040',
#   '5211430000',
#   '7207191900',
#   '7312108902',
#   '7407100000',
#   '8465912000',
#   '9032102000'],
#  ['3301139000',
#   '4408101500',
#   '4408398502',
#   '5407730000',
#   '5515113000',
#   '8446300000',
#   '8535400000'],
#  ['3702390000',
#   '3824810000',
#   '5515992000',
#   '6301409000',
#   '8423811000',
#   '9004109900'],
#  ['3904501000', '4823701000', '8473308001', '8702109199'],
#  ['3909509000',
#   '4403995101',
#   '6006341000',
#   '7318190001',
#   '8450200000',
#   '8708922001'],
#  ['3912201100',
#   '7226198000',
#   '7315810000',
#   '7320208902',
#   '8101960000',
#   '8511800009',
#   '8708309909',
#   '8708505509'],
#  ['4012110000', '8486400002', '8708923501'],
#  ['4407941000',
#   '4705000000',
#   '5101190000',
#   '6909110000',
#   '8414401000',
#   '8708939001'],
#  ['4411141000', '5208119000', '7225191000'],
#  ['4901990000', '8433191000'],
#  ['5208329900', '6204210000', '8414302002', '8455210009'],
#  ['5212131000', '5803009000', '8310000000'],
#  ['5309111000', '6211329000', '7318210009', '8433600000'],
#  ['5911329000', '6207910000', '8480710000', '9506620000'],
#  ['6112491000', '7312900000', '8448490000', '8704213908', '8716903000'],
#  ['7307931100', '8423900009', '8445130002'],
#  ['8102940000', '8504229000'],
#  ['8418610019'],
#  ['8419812009', '8462411001'],
#  ['9006610000'],
#  ['9405105009']]

# %%
docs = df_raw["tokens"].values
tokenized_docs = df_raw["tokens"].values
vocab = Counter()
for token in tokenized_docs:
    vocab.update(token)

# %% [markdown]
# ## Build word2vec Embeddings for Products

# %%
# train word2vec model
model = Word2Vec(window = 10, sg = 1, hs = 0,
                 negative = 10, # for negative sampling
                 alpha=0.03, min_alpha=0.0007,
                 seed = 14)

# %%
model.build_vocab(tokenized_docs)

# %%
model.train(tokenized_docs, total_examples=model.corpus_count, epochs=30, report_delay=1)
# Out:
# (6879091, 7517850)

# %%
# save word2vec model
model.save("word2vec_2.model")

# %% [markdown]
# As we do not plan to train the model any further, we are calling init_sims(), which will make the model much more memory-efficient.

# %%
model.init_sims(replace=True)

# %%
print(model)
# Out:
# Word2Vec(vocab=5634, size=100, alpha=0.03)

# %% [markdown]
# Now we will extract the vectors of all the words in our vocabulary and store it in one place for easy access.

# %%
# extract all vectors
X = model[model.wv.vocab]

X.shape
# Out:
# (5634, 100)

# %%
model.wv.similar_by_vector("купить")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-0baff257e7af> in <module>
# ----> 1 model.wv.similar_by_vector("купить")
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in similar_by_vector(self, vector, topn, restrict_vocab)
#     620
#     621         """
# --> 622         return self.most_similar(positive=[vector], topn=topn, restrict_vocab=restrict_vocab)
#     623
#     624     @deprecated(
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'купить' not in vocabulary"

# %% [markdown]
# ## Visualize word2vec Embeddings

# %% [markdown]
# It is always quite helpful to visualize the embeddings that you have created. Over here we have 100 dimensional embeddings. We can't even visualize 4 dimensions let alone 100. Therefore, we are going to reduce the dimensions of the product embeddings from 100 to 2 by using the UMAP algorithm, it is used for dimensionality reduction.

# %%
import umap

cluster_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0,
                              n_components=2, random_state=42).fit_transform(X)

plt.figure(figsize=(10,9))
plt.scatter(cluster_embedding[:, 0], cluster_embedding[:, 1], s=3, cmap='Spectral')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-97-5536d13e0931> in <module>
# ----> 1 import umap
#       2
#       3 cluster_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0,
#       4                               n_components=2, random_state=42).fit_transform(X)
#       5
#
# ModuleNotFoundError: No module named 'umap'

# %% [markdown]
# Every dot in this plot is a product. As you can see, there are several tiny clusters of these datapoints. These are groups of similar products.

# %% [markdown]
# ## Start Recommending Products

# %% [markdown]
# Congratulations! We are finally ready with the word2vec embeddings for every product in our online retail dataset. Now our next step is to suggest similar products for a certain product or a product's vector.

# %% [markdown]
# Let's first create a product-ID and product-description dictionary to easily map a product's description to its ID and vice versa.

# %%
products = train_df[["TNVED", "FULL_TEXT"]]

# remove duplicates
products.drop_duplicates(inplace=True, subset='TNVED', keep="last")

# create product-ID and product-description dictionary
products_dict = products.groupby('TNVED')['FULL_TEXT'].apply(list).to_dict()

# %%
# test the dictionary
products_dict['0101210000']
# Out:
# [' ЛОШАДИ, ОСЛЫ, МУЛЫ И ЛОШАКИ ЖИВЫЕ: ЛОШАДИ: ЧИСТОПОРОДНЫЕ ПЛЕМЕННЫЕ ЖИВОТНЫЕ']

# %% [markdown]
# <br>
#
# I have defined the function below. It will take a product's vector (n) as input and return top 6 similar products.

# %% [markdown]
# Let's try out our function by passing the vector of the product '90019A' ('SILVER M.O.P ORBIT BRACELET')

# %% [markdown]
# <br>
#
# Cool! The results are pretty relevant and match well with the input product. However, this output is based on the vector of a single product only. What if we want recommend a user products based on the multiple purchases he or she has made in the past?
#
# One simple solution is to take average of all the vectors of the products he has bought so far and use this resultant vector to find similar products. For that we will use the function below that takes in a list of product ID's and gives out a 100 dimensional vector which is mean of vectors of the products in the input list.

# %%
def aggregate_vectors(products):
    product_vec = []
    for i in products:
        try:
            product_vec.append(model[i])
        except KeyError:
            continue
        
    return np.mean(product_vec, axis=0)

# %% [markdown]
# If you can recall, we have already created a separate list of purchase sequences for validation purpose. Now let's make use of that.

# %%
len(purchases_val[0])
# Out:
# 314

# %% [markdown]
# The length of the first list of products purchased by a user is 314. We will pass this products' sequence of the validation set to the function *aggregate_vectors*.

# %%
aggregate_vectors(purchases_val[0]).shape
# Out:
# (100,)

# %% [markdown]
# Well, the function has returned an array of 100 dimension. It means the function is working fine. Now we can use this result to get the most similar products. Let's do it.

# %%
similar_products(aggregate_vectors(purchases_val[0]))
# Out:
# [('PARTY BUNTING', 0.661663293838501),
#  ('ALARM CLOCK BAKELIKE RED ', 0.640213131904602),
#  ('ALARM CLOCK BAKELIKE IVORY', 0.6287959814071655),
#  ('ROSES REGENCY TEACUP AND SAUCER ', 0.6286610960960388),
#  ('SPOTTY BUNTING', 0.6270893216133118),
#  ('GREEN REGENCY TEACUP AND SAUCER', 0.6261675357818604)]

# %% [markdown]
# As it turns out, our system has recommended 6 products based on the entire purchase history of a user. Moreover, if you want to get products suggestions based on the last few purchases only then also you can use the same set of functions.
#
# Below I am giving only the last 10 products purchased as input.

# %%
similar_products(aggregate_vectors(purchases_val[0][-10:]))
# Out:
# [('PARISIENNE KEY CABINET ', 0.6296610832214355),
#  ('FRENCH ENAMEL CANDLEHOLDER', 0.6204789876937866),
#  ('VINTAGE ZINC WATERING CAN', 0.5855435729026794),
#  ('CREAM HANGING HEART T-LIGHT HOLDER', 0.5839680433273315),
#  ('ENAMEL FLOWER JUG CREAM', 0.5806118845939636)]

# %% [markdown]
# Feel free to play this code, try to get product recommendation for more sequences from the validation set
